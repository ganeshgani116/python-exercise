# %% [markdown]
# ![image3.png](attachment:image3.png)

# %%
import numpy as np

# %% [markdown]
# ## TASK-1

# %%
array_1 = np.random.randint(1,15,10)

# %%
array_1
# Out:
# array([ 8,  4, 11, 12, 11,  9,  1, 13,  9, 11])

# %%
array_2 = np.random.randint(1,20,10)

# %%
array_2
# Out:
# array([ 6,  4, 16, 12,  7, 15, 19, 14,  4, 18])

# %% [markdown]
# #### addition

# %%
array_1 + array_2
# Out:
# array([14,  8, 27, 24, 18, 24, 20, 27, 13, 29])

# %%
np.add(array_1,array_2)
# Out:
# array([14,  8, 27, 24, 18, 24, 20, 27, 13, 29])

# %% [markdown]
# #### substraction

# %%
array_1 - array_2
# Out:
# array([  2,   0,  -5,   0,   4,  -6, -18,  -1,   5,  -7])

# %%
np.subtract(array_1,array_2)
# Out:
# array([  2,   0,  -5,   0,   4,  -6, -18,  -1,   5,  -7])

# %% [markdown]
# #### multiplication

# %%
array_1 * array_2
# Out:
# array([ 48,  16, 176, 144,  77, 135,  19, 182,  36, 198])

# %%
np.multiply(array_1,array_2)
# Out:
# array([ 48,  16, 176, 144,  77, 135,  19, 182,  36, 198])

# %% [markdown]
# #### division

# %%
array_1 / array_2
# Out:
# array([1.33333333, 1.        , 0.6875    , 1.        , 1.57142857,
#        0.6       , 0.05263158, 0.92857143, 2.25      , 0.61111111])

# %%
array_1 // array_2
# Out:
# array([1, 1, 0, 1, 1, 0, 0, 0, 2, 0])

# %%
array_1 % array_2
# Out:
# array([ 2,  0, 11,  0,  4,  9,  1, 13,  1, 11])

# %%
np.divide(array_1,array_2)
# Out:
# array([1.33333333, 1.        , 0.6875    , 1.        , 1.57142857,
#        0.6       , 0.05263158, 0.92857143, 2.25      , 0.61111111])

# %% [markdown]
# ## TASK-2

# %%
arr1 = np.random.randint(1,15,9).reshape(3,3)

# %%
arr1
# Out:
# array([[ 5, 14, 12],
#        [ 6,  6,  9],
#        [10,  4,  5]])

# %%
arr2 = np.random.randint(1,10,3).reshape(1,3)

# %%
arr2
# Out:
# array([[2, 9, 7]])

# %%
arr1 + arr2
# Out:
# array([[ 7, 23, 19],
#        [ 8, 15, 16],
#        [12, 13, 12]])

# %% [markdown]
# ## TASK-3

# %%
arr = np.random.randint(1,50,25).reshape(5,5)

# %%
arr
# Out:
# array([[ 5,  5, 42,  1, 41],
#        [14, 45, 33, 27, 44],
#        [35, 43,  7, 48, 14],
#        [40,  8, 32, 49, 11],
#        [32, 22, 24, 41,  2]])

# %%
np.sum(arr)
# Out:
# 665

# %%
np.mean(arr)
# Out:
# 26.6

# %%
np.max(arr)
# Out:
# 49

# %%
np.min(arr)
# Out:
# 1

# %%
np.sum(arr,axis=0)
# Out:
# array([126, 123, 138, 166, 112])

# %%
np.mean(arr,axis = 0)
# Out:
# array([25.2, 24.6, 27.6, 33.2, 22.4])

# %%
np.max(arr,axis = 0)
# Out:
# array([40, 45, 42, 49, 44])

# %%
np.min(arr,axis = 0)
# Out:
# array([5, 5, 7, 1, 2])

# %%
np.sum(arr,axis=1)
# Out:
# array([ 94, 163, 147, 140, 121])

# %%
np.mean(arr,axis=1)
# Out:
# array([18.8, 32.6, 29.4, 28. , 24.2])

# %%
np.max(arr,axis = 1)
# Out:
# array([42, 45, 48, 49, 41])

# %%
np.min(arr,axis = 1)
# Out:
# array([ 1, 14,  7,  8,  2])

# %% [markdown]
# ## TASK-4

# %%
bool_arr1 = np.random.choice([True, False], size=(3,3))

# %%
bool_arr1
# Out:
# array([[ True,  True,  True],
#        [ True,  True, False],
#        [False, False,  True]])

# %%
bool_arr2 = np.random.choice([True, False], size=(3,3))

# %%
bool_arr2
# Out:
# array([[ True, False,  True],
#        [ True, False, False],
#        [False, False,  True]])

# %%
np.logical_and(bool_arr1,bool_arr2)
# Out:
# array([[ True, False,  True],
#        [ True, False, False],
#        [False, False,  True]])

# %%
np.logical_or(bool_arr1,bool_arr2)
# Out:
# array([[ True,  True,  True],
#        [ True,  True, False],
#        [False, False,  True]])

# %%
np.logical_not(bool_arr1,bool_arr2)
# Out:
# array([[False, False, False],
#        [False, False,  True],
#        [ True,  True, False]])

# %% [markdown]
# ## TASK-5

# %%
arr1 = np.random.randint(1,20,10)
arr1
# Out:
# array([ 9, 16,  8, 16,  2, 15, 18, 11,  4, 16])

# %%
arr2 =  np.random.randint(1,25,10)
arr2
# Out:
# array([22,  9, 13, 13, 24,  1,  3,  1,  3,  8])

# %%
arr1 == arr2
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False])

# %%
arr1 != arr2
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
arr1 > arr2
# Out:
# array([False,  True, False,  True, False,  True,  True,  True,  True,
#        False])

# %%
arr1 < arr2
# Out:
# array([ True, False,  True, False,  True, False, False, False, False,
#         True])

# %% [markdown]
# ## TASK-6

# %%
arr = np.random.randint(1,15,10)

# %%
arr
# Out:
# array([10,  3,  1,  3, 11,  6,  5, 12, 13, 11])

# %%
condition = arr > 10

# %%
n = np.where(condition)[0]

# %%
n1 = arr[n]

# %%
print(arr)
print("Indices of elements greater than the threshold:",n)
print("Elements greater than the threshold:",n1)
# Out:
# [10  3  1  3 11  6  5 12 13 11]
# Indices of elements greater than the threshold: [4 7 8 9]
# Elements greater than the threshold: [11 12 13 11]

# %% [markdown]
# ## TASK-7

# %%
original_array = np.random.randint(1,25,12).reshape(3,4)

# %%
original_array
# Out:
# array([[14,  2, 12, 13],
#        [19, 23,  9, 24],
#        [24, 14,  1,  5]])

# %%
Reshape_original_array = original_array.reshape(4,3)

# %%
Reshape_original_array
# Out:
# array([[14,  2, 12],
#        [13, 19, 23],
#        [ 9, 24, 24],
#        [14,  1,  5]])

# %%
transpose_array =  np.transpose(Reshape_original_array)

# %%
transpose_array
# Out:
# array([[14, 13,  9, 14],
#        [ 2, 19, 24,  1],
#        [12, 23, 24,  5]])

# %%
transpose_array == original_array
# Out:
# array([[ True, False, False, False],
#        [False, False, False, False],
#        [False, False, False,  True]])

# %%
transpose_array != original_array
# Out:
# array([[False,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True, False]])

# %%
transpose_array > original_array
# Out:
# array([[False,  True, False,  True],
#        [False, False,  True, False],
#        [False,  True,  True, False]])

# %%
transpose_array < original_array
# Out:
# array([[False, False,  True, False],
#        [ True,  True, False,  True],
#        [ True, False, False, False]])

# %% [markdown]
# ## TASK-8

# %%
arr1 = np.random.randint(1,10,9).reshape(3,3)

# %%
arr1
# Out:
# array([[9, 3, 7],
#        [3, 8, 6],
#        [5, 1, 4]])

# %%
arr2 = np.random.randint(1,10,9).reshape(3,3)

# %%
arr2
# Out:
# array([[6, 5, 5],
#        [5, 3, 4],
#        [9, 4, 3]])

# %%
arr1 * arr2
# Out:
# array([[54, 15, 35],
#        [15, 24, 24],
#        [45,  4, 12]])

# %%
np.dot(arr1,arr2)
# Out:
# array([[132,  82,  78],
#        [112,  63,  65],
#        [ 71,  44,  41]])

# %%
np.linalg.inv(arr1)
# Out:
# array([[ 0.89655172, -0.17241379, -1.31034483],
#        [ 0.62068966,  0.03448276, -1.13793103],
#        [-1.27586207,  0.20689655,  2.17241379]])

# %%
np.linalg.inv(arr2)
# Out:
# array([[-0.25      ,  0.17857143,  0.17857143],
#        [ 0.75      , -0.96428571,  0.03571429],
#        [-0.25      ,  0.75      , -0.25      ]])
